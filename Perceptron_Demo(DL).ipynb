# %% [markdown]
# <a href="https://colab.research.google.com/github/Nishanta04/Deep-Learning/blob/main/Perceptron_Demo(DL).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('placement.csv')
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
sns.scatterplot(x=df['cgpa'], y=df['resume_score'], hue=df['placed'])
# Out:
# <Axes: xlabel='cgpa', ylabel='resume_score'>

# %%
a = df.iloc[:,0:2]
b = df.iloc[:,-1]

# %%
from sklearn.linear_model import Perceptron
p = Perceptron()

# %%
p.fit(a,b)
# Out:
# Perceptron()

# %%
# Weights (w1 and w2)
p.coef_
# Out:
# array([[ 40.26, -36.  ]])

# %%
# Bias
p.intercept_
# Out:
# array([-25.])

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(a.values, b.values, clf=p)
plt.xlabel('CGPA')
plt.ylabel('Resume Score')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
